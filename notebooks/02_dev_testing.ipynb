# %% [markdown]
# ## Import Libraries

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
from IPython.display import display, HTML
import sys
sys.path.append("../src")
from vibe_engine_full import VibeEngine

# %% [markdown]
# ## Data

# %%
csv_path = "../data/spotify_tracks.csv"

df = pd.read_csv(csv_path)
df_tracks = df.dropna().reset_index(drop=True)
del df_tracks[df_tracks.columns[0]]
df_tracks.head()
# Out:
#                  track_id                 artists  \
# 0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# 3  Can't Help Falling In Love          71       201933     False
# 4                     Hold On          82       198853     False
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.676  0.4610    1    -6.746     0       0.1430        0.0322
# 1         0.420  0.1660    1   -17.235     1       0.0763        0.9240
# 2         0.438  0.3590    0    -9.734     1       0.0557        0.2100
# 3         0.266  0.0596    0   -18.515     1       0.0363        0.9050
# 4         0.618  0.4430    2    -9.681     1       0.0526        0.4690
#
#    instrumentalness  liveness  valence    tempo  time_signature track_genre
# 0          0.000001    0.3580    0.715   87.917               4    acoustic
# 1          0.000006    0.1010    0.267   77.489               4    acoustic
# 2          0.000000    0.1170    0.120   76.332               4    acoustic
# 3          0.000071    0.1320    0.143  181.740               3    acoustic
# 4          0.000000    0.0829    0.167  119.949               4    acoustic

# %% [markdown]
# ## NOTES
# - pre-set sliders when user opens (randomized, need creative, fun, engaging call for action) or will this be the same as mode 2b?
# - drop null, first col in df for all modes

# %% [markdown]
# ## Initialization

# %%
engine = VibeEngine(df_tracks)

print("VibeEngine initialized.")
print("Num tracks:", engine.X.shape[0])
print("Num vibe dims:", engine.X.shape[1])
print("Vibe cols:", engine.vibe_cols)
print("Has track_id mapping:", len(engine.trackid_to_idx) > 0)
# Out:
# VibeEngine initialized.
# Num tracks: 113999
# Num vibe dims: 7
# Vibe cols: ['danceability', 'energy', 'valence', 'tempo', 'acousticness', 'instrumentalness', 'speechiness']
# Has track_id mapping: True

# %% [markdown]
# ## Mode 1

# %%
from mode1_sliders_full import SliderVibeRecommender

mode1 = SliderVibeRecommender(df_tracks)

sliders = {
    "danceability": 80,
    "energy": 75,
    "valence": 70,
    "tempo": 65,
    "acousticness": 20,
    "instrumentalness": 10,
    "speechiness": 15,
}

recs_mode1 = mode1.recommend_by_sliders(
    sliders,
    top_k=10,
    lambda_vibe=0.8,
    hide_explicit=True,
)

recs_mode1[["track_name", "artists", "track_genre", "vibe_score", "vibe_similarity"]].head(10)
# Out:
#                        track_name                artists  track_genre  \
# 89912                     Un Coco              Bad Bunny    reggaeton
# 89771                      Sobrio                 Maluma    reggaeton
# 3255               Feel Good Inc.               Gorillaz  alternative
# 89819                  Se Preparó                  Ozuna    reggaeton
# 81173             I Ain't Worried            OneRepublic          pop
# 20407        Right Now (Na Na Na)                   Akon        dance
# 51122                    Satisfya             Imran Khan      hip-hop
# 104802                No Me Basta  India Martinez;Dvicio      spanish
# 39408   Bamba (feat. Aitch & BIA)      Luciano;Aitch;BIA       german
# 65109                  Black Swan                    BTS        k-pop
#
#         vibe_score  vibe_similarity
# 89912     0.939900         0.957376
# 89771     0.934318         0.965397
# 3255      0.929595         0.951994
# 89819     0.919002         0.961253
# 81173     0.907499         0.894374
# 20407     0.899292         0.946615
# 51122     0.898673         0.948341
# 104802    0.896389         0.975486
# 39408     0.888171         0.900214
# 65109     0.881009         0.916262

# %%
def show_vibe_recs(model, sliders, top_k=10, **kwargs):
    # 1. Get recommendations
    recs = model.recommend_by_sliders(
        sliders,
        top_k=top_k,
        **kwargs,
    )

    if recs.empty:
        print("No recommendations found for this vibe 😢 Try relaxing your filters.")
        return recs
    
def describe_vibe(sliders):
    d = sliders["danceability"]
    e = sliders["energy"]
    v = sliders["valence"]

    mood_bits = []
    if e > 70: mood_bits.append("high energy")
    elif e < 35: mood_bits.append("low energy")

    if d > 70: mood_bits.append("very danceable")
    elif d < 35: mood_bits.append("chill / not very danceable")

    if v > 65: mood_bits.append("generally happy")
    elif v < 35: mood_bits.append("on the sadder side")

    return " • ".join(mood_bits) or "balanced vibe"

# %%
def show_now_playing_and_queue(recs: pd.DataFrame):
    if recs.empty:
        print("No recommendations returned 🙁")
        return

    # row 0 = Now Playing
    now = recs.iloc[0]
    print("🎧 NOW PLAYING")
    print(f"  {now['track_name']} — {now['artists']}")
    print(f"  Genre: {now.get('track_genre', 'N/A')}")
    if "vibe_similarity" in now:
        print(f"   Vibe match: {now['vibe_similarity']:.3f} | Score: {now['vibe_score']:.3f}")
    if "track_id" in now and isinstance(now["track_id"], str):
        url = f"https://open.spotify.com/track/{now['track_id']}"
        display(HTML(f'<p><a href="{url}" target="_blank">▶ Open in Spotify</a></p>'))

    # rows 1–9 = Up Next
    if len(recs) > 1:
        up_next = recs.iloc[1:10][["track_name", "artists", "track_genre", "vibe_score"]]
        print("⬇️ UP NEXT")
        display(up_next.reset_index(drop=True))
    else:
        print("No additional tracks in queue.")

print("Vibe summary:", describe_vibe(sliders))
show_now_playing_and_queue(recs_mode1)
# Out:
# Vibe summary: high energy • very danceable • generally happy
# 🎧 NOW PLAYING
#   Un Coco — Bad Bunny
#   Genre: reggaeton
#    Vibe match: 0.957 | Score: 0.940
# <p><a href="https://open.spotify.com/track/6VrQTLzzuyGIYjUDe4kAZk" target="_blank">▶ Open in Spotify</a></p>
# ⬇️ UP NEXT
#                   track_name                artists  track_genre  vibe_score
# 0                     Sobrio                 Maluma    reggaeton    0.934318
# 1             Feel Good Inc.               Gorillaz  alternative    0.929595
# 2                 Se Preparó                  Ozuna    reggaeton    0.919002
# 3            I Ain't Worried            OneRepublic          pop    0.907499
# 4       Right Now (Na Na Na)                   Akon        dance    0.899292
# 5                   Satisfya             Imran Khan      hip-hop    0.898673
# 6                No Me Basta  India Martinez;Dvicio      spanish    0.896389
# 7  Bamba (feat. Aitch & BIA)      Luciano;Aitch;BIA       german    0.888171
# 8                 Black Swan                    BTS        k-pop    0.881009

# %% [markdown]
# ## Mode 2A

# %%
from mode2a_seed_from_song_full import Mode2ASeedFromSong

mode2a = Mode2ASeedFromSong(engine)
mode2a.df.head()
# Out:
#                  track_id                 artists  \
# 0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# 3  Can't Help Falling In Love          71       201933     False
# 4                     Hold On          82       198853     False
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.676  0.4610    1    -6.746     0       0.1430        0.0322
# 1         0.420  0.1660    1   -17.235     1       0.0763        0.9240
# 2         0.438  0.3590    0    -9.734     1       0.0557        0.2100
# 3         0.266  0.0596    0   -18.515     1       0.0363        0.9050
# 4         0.618  0.4430    2    -9.681     1       0.0526        0.4690
#
#    instrumentalness  liveness  valence    tempo  time_signature track_genre
# 0          0.000001    0.3580    0.715   87.917               4    acoustic
# 1          0.000006    0.1010    0.267   77.489               4    acoustic
# 2          0.000000    0.1170    0.120   76.332               4    acoustic
# 3          0.000071    0.1320    0.143  181.740               3    acoustic
# 4          0.000000    0.0829    0.167  119.949               4    acoustic

# %%
query = "feel good inc"  # or "bad bunny", "taylor swift", etc.

candidates = mode2a.search_tracks(query, max_results=10)
display(candidates[["track_name", "artists", "track_genre", "track_id"]])
# Out:
#           track_name   artists  track_genre                track_id
# 3255  Feel Good Inc.  Gorillaz  alternative  0d28khcov6AiegSCpG5TuT

# %% [markdown]
# ### Use `df_index` as seed

# %%
seed_row = candidates.iloc[0]
seed_track_id = seed_row["track_id"]

print("Using this track_id as seed:", seed_track_id)
print(seed_row[["track_name", "artists", "track_genre"]])

seed_url = f"https://open.spotify.com/track/{seed_track_id}"
print("🔗 Open SEED in Spotify:", seed_url)

now_playing2, up_next2, seed_idx2 = mode2a.recommend_from_seed(
    track_id=seed_track_id,
    top_k=10,
    lambda_vibe=0.8,
    hide_explicit=True,
)

mode2a.print_now_playing_and_queue(
    now_playing=now_playing2,
    up_next=up_next2,
    seed_idx=seed_idx2,
    show_explanation=True,
    show_spotify_embed=True,
)
# Out:
# Using this track_id as seed: 0d28khcov6AiegSCpG5TuT
# track_name     Feel Good Inc.
# artists              Gorillaz
# track_genre       alternative
# Name: 3255, dtype: object
# 🔗 Open SEED in Spotify: https://open.spotify.com/track/0d28khcov6AiegSCpG5TuT
# 🎧 Now playing: Ferrari — James Hype;Miggy Dela Rosa
# ▶ Open in Spotify: https://open.spotify.com/track/4zN21mbAuaD0WqtmaTZZeP
#                 <iframe style="border-radius:12px"
#                         src="https://open.spotify.com/embed/track/4zN21mbAuaD0WqtmaTZZeP?utm_source=generator"
#                         width="100%" height="80" frameborder="0" allowfullscreen=""
#                         allow="autoplay; clipboard-write; encrypted-media; fullscreen; picture-in-picture">
#                 </iframe>
# Recommended **Ferrari** by James Hype;Miggy Dela Rosa because its vibe closely matches *Feel Good Inc.* on: instrumental vibe 🎼, acoustic feel 🎸, energy ⚡.
#
# 🎵 Up Next:
#                                       track_name                 artists  \
# 91002                            I Ain't Worried             OneRepublic
# 89912                                    Un Coco               Bad Bunny
# 20014                   One Kiss (with Dua Lipa)  Calvin Harris;Dua Lipa
# 39408                  Bamba (feat. Aitch & BIA)       Luciano;Aitch;BIA
# 91107                               Stressed Out       Twenty One Pilots
# 85060  Should I Stay or Should I Go - Remastered               The Clash
# 65473                                     Savage                   aespa
# 20960                                   Personal                    HRVY
# 1500                          La Vuelta Al Mundo                Calle 13
#
#       track_genre  vibe_score  vibe_similarity
# 91002        rock    0.920598         0.910747
# 89912   reggaeton    0.918057         0.930071
# 20014       dance    0.916758         0.923448
# 39408      german    0.916688         0.935860
# 91107        rock    0.904524         0.918155
# 85060   punk-rock    0.901865         0.927331
# 65473       k-pop    0.896501         0.935627
# 20960       dance    0.896305         0.945381
# 1500     afrobeat    0.894197         0.942746

# %% [markdown]
# ### Use `track_id` as seed

# %%
seed_row = candidates.iloc[0]
seed_track_id = seed_row["track_id"]

print("Using this track_id as seed:", seed_track_id)
print(seed_row[["track_name", "artists", "track_genre"]])

now_playing2, up_next2, seed_idx2 = mode2a.recommend_from_seed(
    track_id=seed_track_id,
    top_k=10,
    lambda_vibe=0.8,
    hide_explicit=True,
)

mode2a.print_now_playing_and_queue(
    now_playing=now_playing2,
    up_next=up_next2,
    seed_idx=seed_idx2,
    show_explanation=True,
)
# Out:
# Using this track_id as seed: 0d28khcov6AiegSCpG5TuT
# track_name     Feel Good Inc.
# artists              Gorillaz
# track_genre       alternative
# Name: 3255, dtype: object
# 🎧 Now playing: Ferrari — James Hype;Miggy Dela Rosa
# ▶ Open in Spotify: https://open.spotify.com/track/4zN21mbAuaD0WqtmaTZZeP
#                 <iframe style="border-radius:12px"
#                         src="https://open.spotify.com/embed/track/4zN21mbAuaD0WqtmaTZZeP?utm_source=generator"
#                         width="100%" height="80" frameborder="0" allowfullscreen=""
#                         allow="autoplay; clipboard-write; encrypted-media; fullscreen; picture-in-picture">
#                 </iframe>
# Recommended **Ferrari** by James Hype;Miggy Dela Rosa because its vibe closely matches *Feel Good Inc.* on: instrumental vibe 🎼, acoustic feel 🎸, energy ⚡.
#
# 🎵 Up Next:
#                                       track_name                 artists  \
# 91002                            I Ain't Worried             OneRepublic
# 89912                                    Un Coco               Bad Bunny
# 20014                   One Kiss (with Dua Lipa)  Calvin Harris;Dua Lipa
# 39408                  Bamba (feat. Aitch & BIA)       Luciano;Aitch;BIA
# 91107                               Stressed Out       Twenty One Pilots
# 85060  Should I Stay or Should I Go - Remastered               The Clash
# 65473                                     Savage                   aespa
# 20960                                   Personal                    HRVY
# 1500                          La Vuelta Al Mundo                Calle 13
#
#       track_genre  vibe_score  vibe_similarity
# 91002        rock    0.920598         0.910747
# 89912   reggaeton    0.918057         0.930071
# 20014       dance    0.916758         0.923448
# 39408      german    0.916688         0.935860
# 91107        rock    0.904524         0.918155
# 85060   punk-rock    0.901865         0.927331
# 65473       k-pop    0.896501         0.935627
# 20960       dance    0.896305         0.945381
# 1500     afrobeat    0.894197         0.942746

# %% [markdown]
# ## Mode 2B

# %%
from mode2b_vibe_roulette_full import Mode2BVibeRoulette

# %%
engine = SliderVibeRecommender(df_tracks=df_tracks)

# 3. Create Vibe Roulette
roulette = Mode2BVibeRoulette(engine)

# 4. Spin once
now_playing_b, up_next_b, meta_b = roulette.spin(
    top_k=10,
    lambda_vibe=0.8,
    hide_explicit=True,
)

roulette.print_spin_result(now_playing_b, up_next_b, meta_b)
# Out:
# 🎲 Vibe Roulette • Thursday • 01:52 PM
# Context: Weekday afternoon
# Picked persona: **Flow State Focus** — steady, low-distraction beats for deep work
# Vibe: mostly instrumental
#
# 🎧 Now playing: Судно (Борис Рижий) — Molchat Doma
# 🔗 Open in Spotify: https://open.spotify.com/track/1SHB1hp6267UK9bJQUxYvO
#
# 🎵 Up Next:
#                                               track_name             artists  \
# 56155                                             YKWIM?            Yot Club
# 34209                                  Welcome Home, Son        Radical Face
# 38462                                        Cosmic Sass        Good Morning
# 57450                              Chamber Of Reflection         Mac DeMarco
# 79130                                   Hommage d'amitié         Gunnel Boek
# 8916   Ain't No Love In The Heart Of The City - Singl...  Bobby "Blue" Bland
# 84214                                         On the Run          Pink Floyd
# 86300                                              Тоска        Molchat Doma
# 36220                                            Rise Up            Mellowdy
#
#       track_genre  vibe_score  vibe_similarity
# 56155   indie-pop    0.910519         0.928149
# 34209        folk    0.903872         0.952340
# 38462      garage    0.893974         0.979967
# 57450       indie    0.893782         0.912227
# 79130       piano    0.881531         0.934413
# 8916        blues    0.878901         0.951126
# 84214  psych-rock    0.870754         0.935942
# 86300        punk    0.864849         0.916061
# 36220      french    0.862947         0.928684

# %%
engine = SliderVibeRecommender(df_tracks=df_tracks)
roulette = Mode2BVibeRoulette(engine)

now_playing_b, up_next_b, meta_b = roulette.spin(
    top_k=10,
    lambda_vibe=0.8,
    hide_explicit=True,
)

roulette.print_spin_result(now_playing_b, up_next_b, meta_b)
# Out:
# 🎲 Vibe Roulette • Thursday • 02:22 PM
# Context: Weekday afternoon
#
# 📚💻  Persona: **Flow State Focus**
#    steady, low-distraction beats for deep work
#    deep work · steady · instrumental
#
# It’s Thursday • 02:22 PM. The algorithm whispers *Flow State Focus*. Starting with **The Night We Met** by Lord Huron to set the tone.
# Tagline: steady, low-distraction beats for deep work.
# Vibe: balanced vibe.
#
# 🎧 Now playing: The Night We Met — Lord Huron
# 🔗 Open in Spotify: https://open.spotify.com/track/3hRV0jL3vUpRrcy398teAU
#
# ▶️ Embedded player:
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/3hRV0jL3vUpRrcy398teAU"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# ℹ️ Why this track?
# This track lines up strongly on instrumental vibe 🎼, speechiness 🗣️.
#
# 🎵 Up Next:
#                                track_name  \
# 56155                              YKWIM?
# 102151                    Mystery of Love
# 2463          Call It Fate, Call It Karma
# 101000                      Herinneringen
# 79324                             Horizon
# 103006                          All of Me
# 80344               Ek Ajnabee Haseena Se
# 2308                             The 1975
# 56974                             Krystal
# 4011                             Heavenly
# 79116                             Estelle
# 4316                      Cambridge, 1963
# 99160                      Swan Upon Leda
# 112399                                 M.
# 44463                       Burn The Rain
# 5560                     Death Note Theme
# 57801                   I Hear a Symphony
# 81101                       Glimpse of Us
# 12019                               土瓜灣情歌
# 111071                              Tides
# 34564                       Song for Zula
# 90450           (Ghost) Riders In The Sky
# 11298                   Fever To The Form
# 11860                        Small Things
# 456                          Same For You
# 81656                             traitor
# 93202                           До завтра
# 94150                            Oblivion
# 80018   Mere Yaaraa (From "Sooryavanshi")
#
#                                       artists        track_genre  vibe_score  \
# 56155                                Yot Club          indie-pop    0.928631
# 102151                         Sufjan Stevens         songwriter    0.914670
# 2463                              The Strokes           alt-rock    0.906958
# 101000                             Sohn Aelia              sleep    0.888909
# 79324                             Tamara Eden              piano    0.879669
# 103006                            John Legend               soul    0.876030
# 80344              Kishore Kumar;R. D. Burman           pop-film    0.864975
# 2308                                 The 1975           alt-rock    0.861150
# 56974                            Matt Maltese          indie-pop    0.856214
# 4011                     Cigarettes After Sex            ambient    0.854330
# 79116                           Doris Casella              piano    0.849913
# 4316                        Jóhann Jóhannsson            ambient    0.849559
# 99160                                  Hozier  singer-songwriter    0.846640
# 112399                       Anıl Emre Daldal            turkish    0.840041
# 44463                             Kurt Cobain             grunge    0.839180
# 5560                         Yoshihisa Hirano              anime    0.836659
# 57801                                Cody Fry              indie    0.836239
# 81101                                    Joji                pop    0.834974
# 12019                       my little airport           cantopop    0.832685
# 111071                    Bonobo;Jamila Woods           trip-hop    0.832328
# 34564                          Phosphorescent               folk    0.827148
# 90450                            The Ventures        rock-n-roll    0.826663
# 11298                             Nick Mulvey            british    0.825464
# 11860                              Ben Howard            british    0.822515
# 456                                Lee DeWyze           acoustic    0.821185
# 81656                          Olivia Rodrigo                pop    0.820287
# 93202                        Vladimir Troshin            romance    0.818884
# 94150                      Rufi-O;Lily Potter                sad    0.818879
# 80018   Arijit Singh;Neeti Mohan;Rashmi Virag           pop-film    0.817967
#
#         vibe_similarity
# 56155          0.950789
# 102151         0.965837
# 2463           0.953698
# 101000         0.926136
# 79324          0.947086
# 103006         0.882537
# 80344          0.926219
# 2308           0.898937
# 56974          0.900268
# 4011           0.890412
# 79116          0.889891
# 4316           0.926949
# 99160          0.883300
# 112399         0.862551
# 44463          0.911475
# 5560           0.943324
# 57801          0.855299
# 81101          0.808717
# 12019          0.933357
# 111071         0.900411
# 34564          0.878935
# 90450          0.908328
# 11298          0.864330
# 11860          0.893144
# 456            0.913982
# 81656          0.805359
# 93202          0.963605
# 94150          0.858598
# 80018          0.839959
